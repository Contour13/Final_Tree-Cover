# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc

import os
import time
import sys

# %% [markdown]
# 1 -- Spruce/Fir
# 2 -- Lodgepole Pine
# 3 -- Ponderosa Pine
# 4 -- Cottonwood/Willow
# 5 -- Aspen
# 6 -- Douglas-fir
# 7 -- Krummholz

# %%
soilsCovDF = pd.read_csv("Data/soilsCovtype.csv")

# %%
soilsCovDF
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0            2596      51      3                               258
# 1            2590      56      2                               212
# 2            2595      45      2                               153
# 3            2579     132      6                               300
# 4            2606      45      7                               270
# 5            2605      49      4                               234
# 6            2617      45      9                               240
# 7            2612      59     10                               247
# 8            2610     259      1                               120
# 9            2962     148     16                               323
# 10           2900      45     19                               242
# 11           2570     346      2                                 0
# 12           2952     107     11                                42
# 13           2640      80      8                               180
# 14           3008      45     14                               277
# 15           2893     114     16                               108
# 16           2628      30     10                               240
# 17           2818     332     26                                30
# 18           2745     306     11                                67
# 19           2788      13     16                                30
# 20           3073     173     12                               108
# 21           2978      71     10                               426
# 22           3067     164     11                                85
# 23           2998      45      8                               351
# 24           2684      84     12                               150
# 25           2676      42     11                               150
# 26           2909      57     16                               134
# 27           2982      53     14                               240
# 28           3070       0     11                                30
# 29           3057     124     12                               150
# ...           ...     ...    ...                               ...
# 369142       2906      78      7                               242
# 369143       2919      31      4                               408
# 369144       2919      34      5                               384
# 369145       2916      56      5                               361
# 369146       2913      90      1                               335
# 369147       2916     135      3                               309
# 369148       2913     110      8                               283
# 369149       2922      21      6                               402
# 369150       2919      52      8                               376
# 369151       2916      67      5                               350
# 369152       2913     100      4                               323
# 369153       2909      97      6                               295
# 369154       2906      80      4                               268
# 369155       2922      73      7                               390
# 369156       2916      75      8                               362
# 369157       2913      70      5                               335
# 369158       2913      60      5                               306
# 369159       2909      49      5                               277
# 369160       2919      79      7                               361
# 369161       2913      67      5                               331
# 369162       2913      65      4                               301
# 369163       2909      63      4                               272
# 369164       2919     135      6                               351
# 369165       2916     108      5                               323
# 369166       2913      90      3                               295
# 369167       2913      99      5                               268
# 369168       2913     115      4                               285
# 369169       2078      34     10                                 0
# 369170       2080      13     19                                30
# 369171       2076      27     24                                30
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                                    0                              510
# 1                                   -6                              390
# 2                                   -1                              391
# 3                                  -15                               67
# 4                                    5                              633
# 5                                    7                              573
# 6                                   56                              666
# 7                                   11                              636
# 8                                   -1                              607
# 9                                   23                             5916
# 10                                  20                             5199
# 11                                   0                              331
# 12                                   7                             5845
# 13                                  -2                             1092
# 14                                  10                             6371
# 15                                  30                             5066
# 16                                  19                              960
# 17                                  17                             4526
# 18                                  24                             2416
# 19                                   8                             4126
# 20                                  -3                             6836
# 21                                  85                             5742
# 22                                   7                             6811
# 23                                  16                             5842
# 24                                   2                             1677
# 25                                  -5                             1634
# 26                                  23                             5502
# 27                                  63                             5756
# 28                                  -6                             6890
# 29                                  53                             6508
# ...                                ...                              ...
# 369142                               6                             4810
# 369143                              13                             4628
# 369144                              13                             4657
# 369145                              13                             4686
# 369146                              13                             4715
# 369147                              16                             4744
# 369148                              13                             4773
# 369149                              19                             4650
# 369150                              19                             4679
# 369151                              16                             4708
# 369152                              13                             4737
# 369153                               9                             4766
# 369154                               3                             4795
# 369155                              22                             4671
# 369156                              16                             4700
# 369157                              13                             4729
# 369158                              10                             4759
# 369159                               9                             4788
# 369160                              16                             4693
# 369161                              10                             4722
# 369162                              10                             4751
# 369163                               6                             4781
# 369164                              16                             4686
# 369165                              13                             4715
# 369166                              10                             4745
# 369167                              10                             4774
# 369168                              10                             4738
# 369169                               0                              212
# 369170                               0                              192
# 369171                               5                              175
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0                 221             232            148
# 1                 220             235            151
# 2                 220             234            150
# 3                 230             237            140
# 4                 222             225            138
# 5                 222             230            144
# 6                 223             221            133
# 7                 228             219            124
# 8                 216             239            161
# 9                 240             236            120
# 10                221             195            100
# 11                215             235            158
# 12                239             226            116
# 13                231             225            127
# 14                223             208            116
# 15                245             223            102
# 16                217             218            136
# 17                151             197            181
# 18                190             234            184
# 19                203             206            137
# 20                227             246            149
# 21                231             221            121
# 22                230             243            144
# 23                223             222            134
# 24                237             220            113
# 25                222             216            128
# 26                229             203            102
# 27                227             209            112
# 28                204             220            153
# 29                240             231            118
# ...               ...             ...            ...
# 369142            229             228            132
# 369143            219             230            148
# 369144            219             228            146
# 369145            223             229            141
# 369146            221             236            151
# 369147            225             238            148
# 369148            234             231            129
# 369149            216             227            148
# 369150            225             222            131
# 369151            226             229            138
# 369152            227             234            142
# 369153            230             231            135
# 369154            225             232            142
# 369155            229             226            131
# 369156            230             225            127
# 369157            225             230            140
# 369158            224             229            140
# 369159            222             229            143
# 369160            230             227            130
# 369161            226             229            138
# 369162            223             231            143
# 369163            224             231            143
# 369164            230             237            141
# 369165            228             234            141
# 369166            225             234            145
# 369167            228             233            140
# 369168            227             236            144
# 369169            219             218            134
# 369170            198             197            132
# 369171            201             180            105
#
#         Horizontal_Distance_To_Fire_Points   ...     Cover_Type  SoilType  \
# 0                                     6279   ...              5        29
# 1                                     6225   ...              5        29
# 2                                     6172   ...              5        29
# 3                                     6031   ...              2        29
# 4                                     6256   ...              5        29
# 5                                     6228   ...              5        29
# 6                                     6244   ...              5        29
# 7                                     6230   ...              5        29
# 8                                     6096   ...              5        29
# 9                                     3395   ...              2        29
# 10                                    4115   ...              2        29
# 11                                    5745   ...              2        29
# 12                                    3509   ...              2        29
# 13                                    5866   ...              2        29
# 14                                    3036   ...              2        29
# 15                                    4340   ...              2        29
# 16                                    5645   ...              2        29
# 17                                    4978   ...              2        29
# 18                                    6428   ...              2        29
# 19                                    5396   ...              2        29
# 20                                    2735   ...              2        29
# 21                                    3792   ...              2        29
# 22                                    2774   ...              2        29
# 23                                    3721   ...              2        29
# 24                                    5693   ...              2        29
# 25                                    5655   ...              2        29
# 26                                    4084   ...              2        29
# 27                                    3880   ...              2        29
# 28                                    2858   ...              2        29
# 29                                    3211   ...              2        29
# ...                                    ...   ...            ...       ...
# 369142                                4625   ...              2         7
# 369143                                4732   ...              2         7
# 369144                                4710   ...              2         7
# 369145                                4689   ...              2         7
# 369146                                4667   ...              2         7
# 369147                                4646   ...              2         7
# 369148                                4624   ...              2         7
# 369149                                4689   ...              2         7
# 369150                                4668   ...              2         7
# 369151                                4646   ...              2         7
# 369152                                4625   ...              2         7
# 369153                                4603   ...              2         7
# 369154                                4582   ...              2         7
# 369155                                4647   ...              2         7
# 369156                                4625   ...              2         7
# 369157                                4604   ...              2         7
# 369158                                4582   ...              2         7
# 369159                                4561   ...              2         7
# 369160                                4604   ...              2         7
# 369161                                4583   ...              2         7
# 369162                                4561   ...              2         7
# 369163                                4540   ...              2         7
# 369164                                4584   ...              2         7
# 369165                                4562   ...              2         7
# 369166                                4540   ...              2         7
# 369167                                4519   ...              2         7
# 369168                                4520   ...              2         7
# 369169                                 484   ...              6        15
# 369170                                 499   ...              6        15
# 369171                                 516   ...              6        15
#
#         Soil_Type  code       family  sub-family      description  \
# 0              29  7745         Como     Legault  extremely stony
# 1              29  7745         Como     Legault  extremely stony
# 2              29  7745         Como     Legault  extremely stony
# 3              29  7745         Como     Legault  extremely stony
# 4              29  7745         Como     Legault  extremely stony
# 5              29  7745         Como     Legault  extremely stony
# 6              29  7745         Como     Legault  extremely stony
# 7              29  7745         Como     Legault  extremely stony
# 8              29  7745         Como     Legault  extremely stony
# 9              29  7745         Como     Legault  extremely stony
# 10             29  7745         Como     Legault  extremely stony
# 11             29  7745         Como     Legault  extremely stony
# 12             29  7745         Como     Legault  extremely stony
# 13             29  7745         Como     Legault  extremely stony
# 14             29  7745         Como     Legault  extremely stony
# 15             29  7745         Como     Legault  extremely stony
# 16             29  7745         Como     Legault  extremely stony
# 17             29  7745         Como     Legault  extremely stony
# 18             29  7745         Como     Legault  extremely stony
# 19             29  7745         Como     Legault  extremely stony
# 20             29  7745         Como     Legault  extremely stony
# 21             29  7745         Como     Legault  extremely stony
# 22             29  7745         Como     Legault  extremely stony
# 23             29  7745         Como     Legault  extremely stony
# 24             29  7745         Como     Legault  extremely stony
# 25             29  7745         Como     Legault  extremely stony
# 26             29  7745         Como     Legault  extremely stony
# 27             29  7745         Como     Legault  extremely stony
# 28             29  7745         Como     Legault  extremely stony
# 29             29  7745         Como     Legault  extremely stony
# ...           ...   ...          ...         ...              ...
# 369142          7  3501       Gothic         NaN         alluvium
# 369143          7  3501       Gothic         NaN         alluvium
# 369144          7  3501       Gothic         NaN         alluvium
# 369145          7  3501       Gothic         NaN         alluvium
# 369146          7  3501       Gothic         NaN         alluvium
# 369147          7  3501       Gothic         NaN         alluvium
# 369148          7  3501       Gothic         NaN         alluvium
# 369149          7  3501       Gothic         NaN         alluvium
# 369150          7  3501       Gothic         NaN         alluvium
# 369151          7  3501       Gothic         NaN         alluvium
# 369152          7  3501       Gothic         NaN         alluvium
# 369153          7  3501       Gothic         NaN         alluvium
# 369154          7  3501       Gothic         NaN         alluvium
# 369155          7  3501       Gothic         NaN         alluvium
# 369156          7  3501       Gothic         NaN         alluvium
# 369157          7  3501       Gothic         NaN         alluvium
# 369158          7  3501       Gothic         NaN         alluvium
# 369159          7  3501       Gothic         NaN         alluvium
# 369160          7  3501       Gothic         NaN         alluvium
# 369161          7  3501       Gothic         NaN         alluvium
# 369162          7  3501       Gothic         NaN         alluvium
# 369163          7  3501       Gothic         NaN         alluvium
# 369164          7  3501       Gothic         NaN         alluvium
# 369165          7  3501       Gothic         NaN         alluvium
# 369166          7  3501       Gothic         NaN         alluvium
# 369167          7  3501       Gothic         NaN         alluvium
# 369168          7  3501       Gothic         NaN         alluvium
# 369169         15  5151  unspecified         NaN          unknown
# 369170         15  5151  unspecified         NaN          unknown
# 369171         15  5151  unspecified         NaN          unknown
#
#         climatic zone            geologic zone GeoSoils
# 0           subalpine  igneous and metamorphic        1
# 1           subalpine  igneous and metamorphic        1
# 2           subalpine  igneous and metamorphic        1
# 3           subalpine  igneous and metamorphic        1
# 4           subalpine  igneous and metamorphic        1
# 5           subalpine  igneous and metamorphic        1
# 6           subalpine  igneous and metamorphic        1
# 7           subalpine  igneous and metamorphic        1
# 8           subalpine  igneous and metamorphic        1
# 9           subalpine  igneous and metamorphic        1
# 10          subalpine  igneous and metamorphic        1
# 11          subalpine  igneous and metamorphic        1
# 12          subalpine  igneous and metamorphic        1
# 13          subalpine  igneous and metamorphic        1
# 14          subalpine  igneous and metamorphic        1
# 15          subalpine  igneous and metamorphic        1
# 16          subalpine  igneous and metamorphic        1
# 17          subalpine  igneous and metamorphic        1
# 18          subalpine  igneous and metamorphic        1
# 19          subalpine  igneous and metamorphic        1
# 20          subalpine  igneous and metamorphic        1
# 21          subalpine  igneous and metamorphic        1
# 22          subalpine  igneous and metamorphic        1
# 23          subalpine  igneous and metamorphic        1
# 24          subalpine  igneous and metamorphic        1
# 25          subalpine  igneous and metamorphic        1
# 26          subalpine  igneous and metamorphic        1
# 27          subalpine  igneous and metamorphic        1
# 28          subalpine  igneous and metamorphic        1
# 29          subalpine  igneous and metamorphic        1
# ...               ...                      ...      ...
# 369142    montane dry        mixed sedimentary        0
# 369143    montane dry        mixed sedimentary        0
# 369144    montane dry        mixed sedimentary        0
# 369145    montane dry        mixed sedimentary        0
# 369146    montane dry        mixed sedimentary        0
# 369147    montane dry        mixed sedimentary        0
# 369148    montane dry        mixed sedimentary        0
# 369149    montane dry        mixed sedimentary        0
# 369150    montane dry        mixed sedimentary        0
# 369151    montane dry        mixed sedimentary        0
# 369152    montane dry        mixed sedimentary        0
# 369153    montane dry        mixed sedimentary        0
# 369154    montane dry        mixed sedimentary        0
# 369155    montane dry        mixed sedimentary        0
# 369156    montane dry        mixed sedimentary        0
# 369157    montane dry        mixed sedimentary        0
# 369158    montane dry        mixed sedimentary        0
# 369159    montane dry        mixed sedimentary        0
# 369160    montane dry        mixed sedimentary        0
# 369161    montane dry        mixed sedimentary        0
# 369162    montane dry        mixed sedimentary        0
# 369163    montane dry        mixed sedimentary        0
# 369164    montane dry        mixed sedimentary        0
# 369165    montane dry        mixed sedimentary        0
# 369166    montane dry        mixed sedimentary        0
# 369167    montane dry        mixed sedimentary        0
# 369168    montane dry        mixed sedimentary        0
# 369169    montane dry                 alluvium        0
# 369170    montane dry                 alluvium        0
# 369171    montane dry                 alluvium        0
#
# [369172 rows x 24 columns]

# %%
soilsCovDF.Soil_Type.value_counts().plot(kind="bar")
plt.title("Soil Types - All Types")
# Out:
# Text(0.5,1,'Soil Types - All Types')

# %%
soilsCovDF.GeoSoils.value_counts()
# Out:
# 1    325005
# 0     44167
# Name: GeoSoils, dtype: int64

# %%
soilsCovDF.GeoSoils.value_counts().plot(kind="bar")
plt.title("Soil Types - 1 is Igneous/Metamorphic - 0 is 'Other'")
# Out:
# Text(0.5,1,"Soil Types - 1 is Igneous/Metamorphic - 0 is 'Other'")

# %%
(soilsCovDF.GeoSoils.value_counts() / len(soilsCovDF)).plot(kind="bar")
plt.title("Soil Types - % Where '1' is Igneous/Metamorphic - '0' is 'Other'")
# Out:
# Text(0.5,1,"Soil Types - % Where '1' is Igneous/Metamorphic - '0' is 'Other'")

# %%
soilsCovDF.Cover_Type.value_counts().plot(kind="bar")
plt.title("Tree Cover Types")
# Out:
# Text(0.5,1,'Tree Cover Types')

# %%
cat_cols = [
    "Cover_Type",
    "GeoSoils",
    "Wilderness_Area1",
    "Wilderness_Area2",
    "Wilderness_Area3", 
    "Wilderness_Area4" 
]

num_cols = [
    "Elevation", 
    "Aspect", 
    "Slope", 
    "Horizontal_Distance_To_Hydrology",
    "Vertical_Distance_To_Hydrology",  
    "Horizontal_Distance_To_Roadways", 
    "Hillshade_9am",
    "Hillshade_Noon", 
    "Hillshade_3pm", 
    "Horizontal_Distance_To_Fire_Points"
]

# %%
for col in num_cols:
    print(col, len(soilsCovDF.loc[soilsCovDF[col].isna()]))
# Out:
# Elevation 0
# Aspect 0
# Slope 0
# Horizontal_Distance_To_Hydrology 0
# Vertical_Distance_To_Hydrology 0
# Horizontal_Distance_To_Roadways 0
# Hillshade_9am 0
# Hillshade_Noon 0
# Hillshade_3pm 0
# Horizontal_Distance_To_Fire_Points 0

# %% [markdown]
# ### single variable distributions first

# %%
for col in num_cols:
    sns.kdeplot(soilsCovDF[col])
    plt.show()

# %%
cat_cols = [
    "Cover_Type",
    "GeoSoils",
    "Wilderness_Area1",
    "Wilderness_Area2",
    "Wilderness_Area3", 
    "Wilderness_Area4" 
]

for col in cat_cols:
    sns.countplot(col, data=soilsCovDF)
    plt.show()

# %% [markdown]
# Cover Type is missing 1 - Spruce/Fir values. Possibly deleted those in the original scrubbing of data when removing those Cov-Type errors that did not itterate properly.
