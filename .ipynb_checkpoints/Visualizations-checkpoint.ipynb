# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc

import os
import time
import sys

# %% [markdown]
# 1 -- Spruce/Fir
# 2 -- Lodgepole Pine
# 3 -- Ponderosa Pine
# 4 -- Cottonwood/Willow
# 5 -- Aspen
# 6 -- Douglas-fir
# 7 -- Krummholz

# %%
soilsCovDF = pd.read_csv("Data/soilsCovtype.csv")
# Out:
# /Users/Megan/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
soilsCovDF.head()
# Out:
#    Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 0       2596      51      3                               258
# 1       2590      56      2                               212
# 2       2595      45      2                               153
# 3       2579     132      6                               300
# 4       2606      45      7                               270
#
#    Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 0                               0                              510
# 1                              -6                              390
# 2                              -1                              391
# 3                             -15                               67
# 4                               5                              633
#
#    Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 0            221             232            148
# 1            220             235            151
# ...

# %%
soilsCovDF.Soil_Type.value_counts().plot(kind="bar")
plt.title("Soil Types - All Types")
# Out:
# Text(0.5,1,'Soil Types - All Types')

# %%
soilsCovDF.GeoSoils.value_counts()
# Out:
# 1    467469
# 0    113543
# Name: GeoSoils, dtype: int64

# %%
soilsCovDF.GeoSoils.value_counts().plot(kind="bar")
plt.title("Soil Types - 1 is Igneous/Metamorphic - 0 is 'Other'")
# Out:
# Text(0.5,1,"Soil Types - 1 is Igneous/Metamorphic - 0 is 'Other'")

# %%
(soilsCovDF.GeoSoils.value_counts() / len(soilsCovDF)).plot(kind="bar")
plt.title("Soil Types - % Where '1' is Igneous/Metamorphic - '0' is 'Other'")
# Out:
# Text(0.5,1,"Soil Types - % Where '1' is Igneous/Metamorphic - '0' is 'Other'")

# %%
soilsCovDF.Cover_Type.value_counts(sort=False, ascending=True).plot(kind="bar")
plt.title("Tree Cover Types")
# Out:
# Text(0.5,1,'Tree Cover Types')

# %%
cat_cols = [
    "Cover_Type",
    "GeoSoils",
    "Wilderness_Area1",
    "Wilderness_Area2",
    "Wilderness_Area3", 
    "Wilderness_Area4" 
]

num_cols = [
    "Elevation", 
    "Aspect", 
    "Slope", 
    "Horizontal_Distance_To_Hydrology",
    "Vertical_Distance_To_Hydrology",  
    "Horizontal_Distance_To_Roadways", 
    "Hillshade_9am",
    "Hillshade_Noon", 
    "Hillshade_3pm", 
    "Horizontal_Distance_To_Fire_Points"
]

# %%
for col in num_cols:
    print(col, len(soilsCovDF.loc[soilsCovDF[col].isna()]))
# Out:
# Elevation 0
# Aspect 0
# Slope 0
# Horizontal_Distance_To_Hydrology 0
# Vertical_Distance_To_Hydrology 0
# Horizontal_Distance_To_Roadways 0
# Hillshade_9am 0
# Hillshade_Noon 0
# Hillshade_3pm 0
# Horizontal_Distance_To_Fire_Points 0

# %% [markdown]
# ### Plotting Single Variable Distributions

# %%
for col in num_cols:
    sns.kdeplot(soilsCovDF[col])
    plt.show()

# %%
cat_cols = [
    "Cover_Type",
    "GeoSoils",
    "Wilderness_Area1",
    "Wilderness_Area2",
    "Wilderness_Area3", 
    "Wilderness_Area4" 
]

for col in cat_cols:
    sns.countplot(col, data=soilsCovDF)
    plt.show()

# %% [markdown]
# GeoSoils are highly rocky due to igneous/metamorphic category. Cover Type is largely attributed to be Lodgepole Pine and Spruce/Fir in Wilderness areas 1 and 3.

# %% [markdown]
# ### Univariate and multi-variate relationships

# %%
sns.regplot(x="Elevation", y="Cover_Type", data=soilsCovDF, fit_reg=False, y_jitter=0.1)

# %%
sns.regplot(x="Elevation", y="Wilderness_Area1", data=soilsCovDF, fit_reg=False, y_jitter=0.1)

# %% [markdown]
# Wilderness Area 1 appears to have occurences of recorded trees at 2500 meters and above in elevation up to 3700m.

# %%
sns.regplot(x="Elevation", y="Wilderness_Area2", data=soilsCovDF, fit_reg=False, y_jitter=0.1)

# %% [markdown]
# Wilderness Area 2 appears to have occurences of recorded trees at 2900 meters and above in elevation up to 3600m.

# %%
sns.regplot(x="Elevation", y="Wilderness_Area3", data=soilsCovDF, fit_reg=False, y_jitter=0.1)

# %% [markdown]
# Wilderness Area 3 has an interesting split in dataset around 3600 meters. Entire range of trees vary in elevation from 2250 to 3900 meters.

# %%
sns.regplot(x="Elevation", y="Wilderness_Area1", data=soilsCovDF, fit_reg=False, y_jitter=0.1, color="blue"),
sns.regplot(x="Elevation", y="Wilderness_Area2", data=soilsCovDF, fit_reg=False, y_jitter=0.1, color="red"),
sns.regplot(x="Elevation", y="Wilderness_Area3", data=soilsCovDF, fit_reg=False, y_jitter=0.1, color="black"),
sns.regplot(x="Elevation", y="Wilderness_Area4", data=soilsCovDF, fit_reg=False, y_jitter=0.1, color="orange")

# %% [markdown]
# Wilderness Area 4 has recorded trees in low elevations from approximately 1900 meters to 2600 meters. This would suggest that this area is lowest in elevation compared to the other areas studies.

# %%
sns.regplot(x="Horizontal_Distance_To_Hydrology", y="Cover_Type", data=soilsCovDF, fit_reg=False, y_jitter=0.1)

# %% [markdown]
# The lower distances to hydrology suggests that these species are likely in areas that are more wet and/or lower in elevation (i.e. near creeks, river valleys, etc.)

# %%
def makeUniPlot(xinput):
    sns.regplot(x=xinput, y="Cover_Type", data=soilsCovDF, fit_reg=False, y_jitter=0.1, x_jitter=0.1, scatter_kws={"alpha": 0.2})
    plt.show()

# %%
for col in num_cols:
    makeUniPlot(col)

# %% [markdown]
# I don't think I need roadways category as I feel this is unnecessary for analysis. Lower elevations are going to have more roads due to it being easier to build roads and paths compared to higher elevations where severe grading has to occur, etc.

# %%
def makeUniPlot(xinput):
    sns.regplot(x=xinput, y="GeoSoils", data=soilsCovDF, fit_reg=False, y_jitter=0.1, x_jitter=0.1, scatter_kws={"alpha": 0.2})
    plt.show()

# %%
for col in num_cols:
    makeUniPlot(col)

# %%
def makeUniPlot(xinput):
    sns.regplot(x=xinput, y="Wilderness_Area1", data=soilsCovDF, fit_reg=False, y_jitter=0.1, x_jitter=0.1, scatter_kws={"alpha": 0.2})
    plt.show()
    
for col in num_cols:
    makeUniPlot(col)

# %%
def makeUniPlot(xinput):
    sns.regplot(x=xinput, y="Wilderness_Area2", data=soilsCovDF, fit_reg=False, y_jitter=0.1, x_jitter=0.1, scatter_kws={"alpha": 0.2})
    plt.show()
    
for col in num_cols:
    makeUniPlot(col)

# %%
plt.scatter(x=soilsCovDF.Slope, y=soilsCovDF.Cover_Type, c=soilsCovDF.Hillshade_9am, cmap="bwr")

# %% [markdown]
# The more red the Hillshade value - the lighter it is. The bluer the Hillshade value, the more shade there is.

# %%
sns.violinplot(x="GeoSoils", y="Elevation", data=soilsCovDF, hue="Cover_Type")

# %%
sns.violinplot(x="Wilderness_Area1", y="Elevation", data=soilsCovDF, hue="GeoSoils")

# %%
cat_cols = [
    "Cover_Type",
    "GeoSoils",
    "Wilderness_Area1",
    "Wilderness_Area2",
    "Wilderness_Area3", 
    "Wilderness_Area4" 
]

num_cols = [
    "Elevation", 
    "Aspect", 
    "Slope", 
    "Horizontal_Distance_To_Hydrology",
    "Vertical_Distance_To_Hydrology",  
    "Horizontal_Distance_To_Roadways", 
    "Hillshade_9am",
    "Hillshade_Noon", 
    "Hillshade_3pm", 
    "Horizontal_Distance_To_Fire_Points"
]
